# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clonning project from github
# !git clone https://github.com/baolam/diffusion-learn diffusion
# Out:
# Cloning into 'diffusion'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 84 (delta 34), reused 67 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 15.01 KiB | 5.00 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
# %cd /content/diffusion
# !mv * .* /content/
# %cd /content
# Out:
# /content/diffusion
# mv: cannot move '.' to '/content/.': Device or resource busy
# mv: cannot move '..' to '/content/..': Device or resource busy
# /content

# %%
# !python -m tools.train_ddpm
# Out:
# ...
# {'dataset_params': {'im_path': 'data/train/images'}, 'diffusion_params': {'num_timesteps': 1000, 'beta_start': 0.0001, 'beta_end': 0.02}, 'model_params': {'im_channels': 1, 'im_size': 28, 'down_channels': [32, 64, 128, 256], 'mid_channels': [256, 256, 128], 'down_sample': [True, True, False], 'time_emb_dim': 128, 'num_down_layers': 2, 'num_mid_layers': 2, 'num_up_layers': 2, 'num_heads': 4}, 'train_params': {'task_name': 'default', 'batch_size': 64, 'num_epochs': 40, 'num_samples': 100, 'num_grid_rows': 10, 'lr': 0.0001, 'ckpt_name': 'checkpoints/ddpm_ckpt.pth'}}
# ...
# Running at device:  cuda
# 100% 9.91M/9.91M [00:01<00:00, 5.55MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 130kB/s]
# 100% 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 17.0MB/s]
# Total images: 60000
# ...

# %%
# Hy vọng chương trình sẽ không dừng ::))))
# Tiếp tục huấn luyện thôi ::)))), được 21 epoch rùi, haha
